# %% [markdown]
# ## Introduction to Plotting
#
# ### Python Packages for plotting
# - `matplotlib`: All plots in pandas are matplotlib objects
# - `seaborn`: Focused on statistical visualization
# - `boken`: To create interactive visualization for the internet
# - `Plotly`: Create interactive and embedded visualization

# %% [markdown]
# ### Matplotlib
# Main submodule is `pyplot` which will give you different function to work in different plot elements.

# %% [markdown]
# ### Creating a Plot
# - Import the necessary packages
# - Import or create the data
# - Call the appropriate plotting functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Display the plots inside the notebook
# %matplotlib inline

# %%
# Dummy data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]
print(x)
print(y)
# Out:
# [1, 2, 3, 4, 5]
# [10, 20, 25, 30, 35]

# %%
# Default is line plot
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Test data
# Get the data from:
# `icarus.cs.weber.edu/~hvalle/cs4580/data/plottingDemo01.zip`

# %%
# Load the data
hw_df = pd.read_csv('../data/hw.csv')

hw_df.head()
# Out:
#    Index   Height(Inches)"   "Weight(Pounds)"
# 0      1             65.78             112.99
# 1      2             71.52             136.49
# 2      3             69.40             153.03
# 3      4             68.22             142.34
# 4      5             67.79             144.30

# %%
# Sample plot
hw_df.plot()
plt.show()

# %%
# Get data from: http://icarus.cs.weber.edu/~hvalle/cs4580/data/plottingDemo01.zip
homes_df = pd.read_csv('../data/homes.csv')
homes_df.head()
# Out:
#    Sell  List  Living  Rooms  Beds  Baths  Age  Acres  Taxes
# 0   142   160      28     10     5      3   60   0.28   3167
# 1   175   180      18      8     4      1   12   0.43   4033
# 2   129   132      13      6     3      1   41   0.33   1471
# 3   138   140      17      7     3      1   22   0.46   3204
# 4   232   240      25      8     4      3    5   2.05   3613

# %% [markdown]
# ## Scatter Plots
# Useful for visualizing relationships between data points.

# %%
# Plot data
homes_df.plot()
# Out:
# <Axes: >

# %%
# Specify the x and y axis labels
homes_df.plot(x='List', y='Rooms')
# Out:
# <Axes: xlabel='List'>

# %%
# Add markers
homes_df.plot(x='List', y='Rooms', markers='o', markerfacecolor='r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Add markers
# ----> 2 homes_df.plot(x='List', y='Rooms', markers='o', markerfacecolor='r')
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1544, in LinePlot._make_plot(self, fig)
#    1541 label = self._mark_right_label(label, index=i)
#    1542 kwds["label"] = label
# -> 1544 newlines = plotf(
#    1545     ax,
#    1546     x,
#    1547     y,
#    1548     style=style,
#    1549     column_num=i,
#    1550     stacking_id=stacking_id,
#    1551     is_errorbar=is_errorbar,
#    1552     **kwds,
#    1553 )
#    1554 self._append_legend_handles_labels(newlines[0], label)
#    1556 if self._is_ts_plot():
#    1557     # reset of xlim should be used for ts data
#    1558     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1580, in LinePlot._plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1578     cls._initialize_stacker(ax, stacking_id, len(y))
#    1579 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1580 lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1581 cls._update_stacker(ax, stacking_id, y)
#    1582 return lines
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\pandas\plotting\_matplotlib\converter.py:95, in register_pandas_matplotlib_converters.<locals>.wrapper(*args, **kwargs)
#      92 @functools.wraps(func)
#      93 def wrapper(*args, **kwargs):
#      94     with pandas_converters():
# ---> 95         return func(*args, **kwargs)
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\pandas\plotting\_matplotlib\core.py:975, in MPLPlot._plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     972 else:
#     973     # prevent style kwarg from going to errorbar, where it is unsupported
#     974     args = (x, y, style) if style is not None else (x, y)
# --> 975     return ax.plot(*args, **kwds)
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\axes\_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\axes\_base.py:534, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     532     return list(result)
#     533 else:
# --> 534     return [l[0] for l in result]
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\axes\_base.py:534, in <listcomp>(.0)
#     532     return list(result)
#     533 else:
# --> 534     return [l[0] for l in result]
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\axes\_base.py:527, in <genexpr>(.0)
#     522 else:
#     523     raise ValueError(
#     524         f"label must be scalar or have the same length as the input "
#     525         f"data, but found {len(label)} for {n_datasets} datasets.")
# --> 527 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     528                       {**kwargs, 'label': label})
#     529           for j, label in enumerate(labels))
#     531 if return_kwargs:
#     532     return list(result)
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\axes\_base.py:335, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     333 kw = {**kw, **kwargs}  # Don't modify the original kw.
#     334 self._setdefaults(self._getdefaults(kw), kw)
# --> 335 seg = mlines.Line2D(x, y, **kw)
#     336 return seg, kw
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\lines.py:407, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     403 self.set_markeredgewidth(markeredgewidth)
#     405 # update kwargs before updating data to give the caller a
#     406 # chance to init axes (and hence unit support)
# --> 407 self._internal_update(kwargs)
#     408 self.pickradius = pickradius
#     409 self.ind_offset = 0
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File c:\Users\gaith\anaconda3\envs\module4\Lib\site-packages\matplotlib\artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'markers'

# %% [markdown]
# ### Bar Plot
# Useful when you are showing or comparing segments of information or categorical data

# %%
# Load data
cities_df = pd.read_csv('../data/cities.csv')
cities_df.head()
# Out:
#         City  Year  Population
# 0  Charlotte  2015      825668
# 1  Charlotte  2016      843117
# 2  Charlotte  2017      860002
# 3  Charlotte  2018      872514
# 4  Charlotte  2019      885708

# %%
# Filter records from Year = 2019
cities_2019_df = cities_df[cities_df['Year'] == 2019]
cities_2019_df.head()
# Out:
#              City  Year  Population
# 4       Charlotte  2019      885708
# 9   San Francisco  2019      881549
# 14   Indianapolis  2019      876384
# 19        Seattle  2019      753675
# 24         Denver  2019      727211

# %%
# Now plot the bar chart of the number of cities in each region
cities_2019_df.plot(kind='bar', x='City', y='Population', title='Population of Cities in 2019', figsize=[10,6])
plt.show()

# %%
# You may want to plot data horizontally
# Since we are only plotting one set of values, we do not need the legend
cities_2019_df.plot(kind='bar', x='City', y='Population', title='Population of Cities in 2019', legend=False, figsize=[10,6])
plt.show()

# %% [markdown]
# ### Scatter Plots
# when you are interested in the relationship between two variables, scatter plots are probably the best choice

# %%
# Load data
houses_df = pd.read_csv('../data/homes.csv')
houses_df.head()
# Out:
#    Sell  List  Living  Rooms  Beds  Baths  Age  Acres  Taxes
# 0   142   160      28     10     5      3   60   0.28   3167
# 1   175   180      18      8     4      1   12   0.43   4033
# 2   129   132      13      6     3      1   41   0.33   1471
# 3   138   140      17      7     3      1   22   0.46   3204
# 4   232   240      25      8     4      3    5   2.05   3613

# %%
# Plot the Scatter Plot
houses_df.plot(kind='scatter', x='List', y='Rooms')
plt.show()

# %%
# Filter data directly
houses_df[houses_df['Age'] < 50].plot(kind='scatter', x='Age', y='List')
plt.show()

# %%
# If you want to eliminate outliers, you can filter the data before plotting
house_plot_df = houses_df[houses_df['Age'] < 50]
house_plot_df = house_plot_df[house_plot_df['List'] < 350]
# Now plot
house_plot_df.plot(kind='scatter', x='Age', y='List')
plt.show()

# %% [markdown]
# ### Histograms
# Use to represent frequency in data

# %%
house_plot_df.head()
# Out:
#    Sell  List  Living  Rooms  Beds  Baths  Age  Acres  Taxes
# 1   175   180      18      8     4      1   12   0.43   4033
# 2   129   132      13      6     3      1   41   0.33   1471
# 3   138   140      17      7     3      1   22   0.46   3204
# 4   232   240      25      8     4      3    5   2.05   3613
# 5   135   140      18      7     4      3    9   0.57   3028

# %%
# If you want to know the distribution of acreage for the houses
# sold in the filtered dataset, use a histogram
house_plot_df['Acres'].plot(kind='hist', title='Acre Distribution for homes < 50 and list < 350')
plt.show()

# %% [markdown]
# ### Area Plot
# Useful when you want to understand how values develop and are composed over time

# %%
## Load data set
enrollments_df = pd.read_csv('../data/enrollment.csv')
enrollments_df.head()
# Out:
#    Year      Class  Enrollment
# 0  2018   Freshman        1500
# 1  2018  Sophomore        1400
# 2  2018     Junior        1300
# 3  2018     Senior        1200
# 4  2019   Freshman        1600

# %%
# Create and area plot of the enrollments
enrollments_df.plot(kind='area', x='Year')
plt.show()

# %%
# Data is not good because it is not organized by year
# We want to see the total, and how it changes over time
# Sort the data by year, then plot it using the pivot method in pandas
pivot_df = enrollments_df.pivot(index='Year', columns='Class', values='Enrollment')
pivot_df.head()
# Out:
# Class  Freshman  Junior  Senior  Sophomore
# Year
# 2018       1500    1300    1200       1400
# 2019       1600    1200    1100       1500
# 2020       1650    1100    1080       1320
# 2021       1400    1100    1150       1390
# 2022       1720    1080     990       1300

# %%
# Plot it
pivot_df.plot(kind='area')
plt.show()

# %%
# The data is stacked by default
# You can set this option to false, stacked=False
pivot_df.plot(kind='area', stacked=False)
plt.show()
